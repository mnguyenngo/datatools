# %%
cd ..
# Out:
# /Users/nguyen/projects/datatools

# %%
from datatools.pdf import pdfminer_helpers

# %%
pdf_file_path = 'data/pdf/2000_3rd_Ave_EG_Team.pdf'

# %%
pdfminer_helpers.get_layouts(pdf_file_path)
# Out:
# [<LTPage(1) 0.000,0.000,612.000,792.000 rotate=0>]

# %%
layouts = _

# %%
layouts
# Out:
# [<LTPage(1) 0.000,0.000,612.000,792.000 rotate=0>]

# %%
pdfminer_helpers.parse_layout(layouts[0])
# Out:
# LTFigure
# (57, 18, 612, 792)
# LTChar
# (491.57363944332, 42.61949548905999, 493.47316004292003, 49.77757594065999)
# LTChar
# (493.47316004292003, 42.61949548905999, 496.32244094232004, 49.77757594065999)
# LTChar
# (496.32244094232004, 42.61949548905999, 499.17172184172006, 49.77757594065999)
# LTChar
# (290.41148652354, 42.928164605452, 294.02592007667045, 48.89272367872479)
# LTChar
# (292.64261834646, 42.928164605452, 295.94965151509916, 48.89272367872479)
# LTChar
# (296.74292375124, 42.928164605452, 300.61517698168564, 48.89272367872479)
# LTChar
# (301.60679351003995, 42.928164605452, 304.08582886883994, 48.89272367872479)
# LTChar
# (305.07744301236, 42.928164605452, 307.3482394010208, 48.89272367872479)
# LTChar
# (310.54622601671997, 42.928164605452, 313.79872040746557, 48.89272367872479)
# LTChar
# (314.69118744564, 42.928164605452, 318.56344067608563, 48.89272367872479)
# LTChar
# (321.41427410268, 42.928164605452, 324.9245881707408, 48.89272367872479)
# LTChar
# ...
